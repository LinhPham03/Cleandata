# %%
import pandas as pd

df = pd.read_csv(r'C:\\Users\\Admin\\Downloads\\OnlineRetail.csv',encoding= 'unicode_escape')
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df.isnull()
# Out:
#         InvoiceNo  StockCode  Description  Quantity  InvoiceDate  UnitPrice  \
# 0           False      False        False     False        False      False
# 1           False      False        False     False        False      False
# 2           False      False        False     False        False      False
# 3           False      False        False     False        False      False
# 4           False      False        False     False        False      False
# ...           ...        ...          ...       ...          ...        ...
# 541904      False      False        False     False        False      False
# 541905      False      False        False     False        False      False
# 541906      False      False        False     False        False      False
# 541907      False      False        False     False        False      False
# 541908      False      False        False     False        False      False
#
#         CustomerID  Country
# ...

# %%
df.dropna()
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# ko thể drop các cột có dữ liệu khuyết thiếu vì sẽ lm mất range dữ liệu

# %%
df.fillna(value = {'Description':'Không biết'})
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
import seaborn as sns
sns.boxplot(x = df['Quantity'])
# Out:
# <AxesSubplot:xlabel='Quantity'>

# %%
import seaborn as sns
sns.boxplot(x = df['UnitPrice'])
# Out:
# <AxesSubplot:xlabel='UnitPrice'>

# %% [markdown]
# - Quantity

# %%
from scipy import stats
z= stats.zscore(df['Quantity'])
z
# Out:
# 0        -0.016289
# 1        -0.016289
# 2        -0.007118
# 3        -0.016289
# 4        -0.016289
#             ...
# 541904    0.011224
# 541905   -0.016289
# 541906   -0.025460
# 541907   -0.025460
# 541908   -0.030045
# Name: Quantity, Length: 541909, dtype: float64

# %%
import numpy as np

# %%
clean_data = np.where((z < 3) | (z > -3))
clean_data
# Out:
# (array([     0,      1,      2, ..., 541906, 541907, 541908], dtype=int64),)

# %%
dirty_data = np.where((z > 3) | (z< -3))
dirty_data
# Out:
# (array([  4287,   4850,   4945,   4946,   6365,   9745,  16427,  16428,
#          16435,  16436,  19149,  19871,  19980,  21518,  25920,  32671,
#          38261,  38463,  38468,  40060,  44863,  44906,  50849,  51049,
#          52131,  52132,  52133,  52134,  52262,  52709,  52710,  52711,
#          52771,  52772,  61619,  61624,  61671,  63444,  65063,  71761,
#          71767,  74614,  74615,  77047,  80665,  80742,  80983,  82205,
#          82208,  82794,  82795,  86503,  86504,  86505,  87631,  89284,
#          90259,  91772,  94765,  97432,  99936, 108088, 109467, 109469,
#         111527, 113580, 114430, 114493, 114538, 114539, 115488, 115505,
#         115807, 115810, 115818, 119154, 121135, 121852, 121853, 121856,
#         121857, 122351, 125146, 125281, 125282, 130911, 131399, 136537,
#         137881, 139503, 140200, 140935, 142700, 142702, 142743, 142749,
#         143520, 150272, 151033, 151038, 154569, 154571, 156350, 160141,
# ...

# %% [markdown]
# - UnitPrice

# %%
u = stats.zscore(df['UnitPrice'])
u
# Out:
# 0        -0.021301
# 1        -0.012620
# 2        -0.019234
# 3        -0.012620
# 4        -0.012620
#             ...
# 541904   -0.038871
# 541905   -0.025952
# 541906   -0.004766
# 541907   -0.004766
# 541908    0.003502
# Name: UnitPrice, Length: 541909, dtype: float64

# %%
clean_data = np.where((u < 3) | (u > -3))
clean_data
# Out:
# (array([     0,      1,      2, ..., 541906, 541907, 541908], dtype=int64),)

# %%
dirty_data = np.where((u > 3) | (u < -3))
dirty_data
# Out:
# (array([  1814,   3041,   4989,   5685,   6165,  10812,  11381,  13924,
#          14392,  14716,  14728,  15016,  15017,  15650,  15985,  16109,
#          16231,  16232,  16313,  16356,  16357,  16778,  18541,  21327,
#          21949,  22062,  22188,  23117,  24907,  27268,  27920,  28992,
#          28993,  28994,  30905,  32484,  34799,  35643,  36159,  36165,
#          36461,  37067,  38249,  38767,  40384,  40494,  40587,  40661,
#          40702,  41448,  42058,  42979,  43702,  43703,  45509,  45622,
#          46366,  47820,  50746,  51636,  53157,  53589,  54859,  55590,
#          56506,  57869,  60380,  60570,  61282,  63984,  64569,  64570,
#          64573,  65420,  65873,  66984,  73446,  82768,  87141,  88210,
#          90557,  90558,  90586,  96677,  96678,  96844,  96845, 104400,
#         106397, 106398, 112229, 112233, 117052, 117053, 117054, 117055,
#         118769, 119631, 119632, 122702, 124024, 124741, 124787, 133994,
# ...
